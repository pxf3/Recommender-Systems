# %%
import pandas as pd
import math

# %%
ratingsFile = pd.read_csv('test.csv')
ratings = ratingsFile.set_index(['userId', 'movieId'])
ratings
# Out:
#                 rating
# userId movieId
# 1      1           1.0
#        2           2.0
#        3           3.0
#        4           4.0
# 2      2           4.0
#        3           3.0
#        4           2.0
#        5           1.0
# 3      1           2.0
#        2           2.0
#        3           5.0
# 4      3           2.0
#        4           2.0
#        5           5.0
# 5      1           3.0
#        3           5.0
#        5           3.0

# %%
math.sqrt((ratings.loc[1]**2).sum())
# Out:
# 5.477225575051661

# %%
dictLength = {}
users = ratings.index.levels[0]
for i in users:
    dictLength[i]=math.sqrt((ratings.loc[i]**2).sum())

# %%
dictMean = {}
users = ratings.index.levels[0]
for i in users:
    dictMean[i]=(ratings.loc[i]).mean()

# %%
ratings2 = ratings.reset_index().sort_values('movieId').set_index(['movieId', 'userId'])
ratings2
# Out:
#                 rating
# movieId userId
# 1       1          1.0
#         5          3.0
#         3          2.0
# 2       2          4.0
#         3          2.0
#         1          2.0
# 3       2          3.0
#         5          5.0
#         3          5.0
#         4          2.0
#         1          3.0
# 4       1          4.0
#         2          2.0
#         4          2.0
# 5       2          1.0
#         4          5.0
#         5          3.0

# %%
dictionary = {}

# %%
dictionary
# Out:
# {}

# %%
dictionary['ricky']='asdf'
dictionary['peng']='adfsad'
dictionary
# Out:
# {'ricky': 'asdf', 'peng': 'adfsad'}

# %%
dictionary['ricky']
# Out:
# 'asdf'

# %%
ratingsFile
# Out:
#     userId  movieId  rating
# 0        1        1     1.0
# 1        1        2     2.0
# 2        1        3     3.0
# 3        1        4     4.0
# 4        2        2     4.0
# 5        2        3     3.0
# 6        2        4     2.0
# 7        2        5     1.0
# 8        3        1     2.0
# 9        3        2     2.0
# 10       3        3     5.0
# 11       4        3     2.0
# 12       4        4     2.0
# 13       4        5     5.0
# 14       5        1     3.0
# 15       5        3     5.0
# 16       5        5     3.0

# %%
ratings
# Out:
#                 rating
# userId movieId
# 1      1           1.0
#        2           2.0
#        3           3.0
#        4           4.0
# 2      2           4.0
#        3           3.0
#        4           2.0
#        5           1.0
# 3      1           2.0
#        2           2.0
#        3           5.0
# 4      3           2.0
#        4           2.0
#        5           5.0
# 5      1           3.0
#        3           5.0
#        5           3.0

# %%
rrr=ratings.groupby('movieId').mean().loc[1]
rrr
# Out:
# rating    2.0
# Name: 1, dtype: float64

# %%
rrr.loc[1]
# Out:
# rating    2.0
# Name: 1, dtype: float64

# %%
ratings.loc[1]
# Out:
#          rating
# movieId
# 1           1.0
# 2           2.0
# 3           3.0
# 4           4.0

# %%
ratings.loc[2]
# Out:
#          rating
# movieId
# 2           4.0
# 3           3.0
# 4           2.0
# 5           1.0

# %%
 = ratings.loc[1].index.intersection(ratings.loc[2].index)
list
# Out:
# Int64Index([2, 3, 4], dtype='int64', name='movieId')

# %%
from typing import Dict
cache: Dict[int, Dict] = {}

# %%
cache = {}
cache[1]={}
cache[1]['2']='3'
cache
# Out:
# {1: {'2': '3'}}

# %%
ttt=ratings.index.levels[0]

# %%
ratings
# Out:
#                 rating
# userId movieId
# 1      1           1.0
#        2           2.0
#        3           3.0
#        4           4.0
# 2      2           4.0
#        3           3.0
#        4           2.0
#        5           1.0
# 3      1           2.0
#        2           2.0
#        3           5.0
# 4      3           2.0
#        4           2.0
#        5           5.0
# 5      1           3.0
#        3           5.0
#        5           3.0

# %%
ratings.index.levels[1]
# Out:
# Int64Index([1, 2, 3, 4, 5], dtype='int64', name='movieId')

# %%
can=[1,2,8,4,5]

# %%
can
# Out:
# [1, 2, 8, 4, 5]

# %%
can2 = can[0:2]

# %%
can2
# Out:
# [1, 2]

# %%
ratings
# Out:
#                 rating
# userId movieId
# 1      1           1.0
#        2           2.0
#        3           3.0
#        4           4.0
# 2      2           4.0
#        3           3.0
#        4           2.0
#        5           1.0
# 3      1           2.0
#        2           2.0
#        3           5.0
# 4      3           2.0
#        4           2.0
#        5           5.0
# 5      1           3.0
#        3           5.0
#        5           3.0

# %%
ratings.loc[1].mean()
# Out:
# rating    2.5
# dtype: float64
