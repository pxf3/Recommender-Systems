# %%
from naive_bayes import NaiveBayesRecommender
import unittest
import pandas as pd

ratings = pd.read_csv('test.csv')
ratings.columns = ['user', 'item', 'rating']

for index, row in ratings.iterrows():
    print(row.iloc[1])
# Out:
# 1.0
# 2.0
# 3.0
# 4.0
# 2.0
# 3.0
# 4.0
# 5.0
# 1.0
# 2.0
# 3.0
# 3.0
# 4.0
# 5.0
# 1.0
# 3.0
# 5.0

# %%
features = pd.read_csv('test_features.csv')
features.columns = ['item', 'feature']
for index, row in features.loc[features['item'] == 1].iterrows():
    print(row.iloc[1])
# Out:
# A
# B
# C
# D
# E
# J
